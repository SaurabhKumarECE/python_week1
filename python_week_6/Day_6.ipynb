# %% [markdown]
# # WEEK 6 – DAY 6
# # Deployment

# %% [markdown]
# ## Objective
#
# Deploy the House Price Prediction application and prepare deployment deliverables.

# %% [markdown]
# ## What is Deployment?
#
# Deployment is the process of making a Machine Learning application available for use.
#
# Deployment can be:
#
# - Local Deployment
# - Cloud Deployment
# - Web Deployment

# %% [markdown]
# ## Deployment Architecture
#
# User
#
# ↓
#
# Streamlit Interface
#
# ↓
#
# Machine Learning Model
#
# ↓
#
# Prediction Result

# %%
import joblib

model = joblib.load(
    "best_house_price_model.pkl"
)

print("Deployment Model Loaded Successfully")
# Out:
# Deployment Model Loaded Successfully

# %%
print("House Price Prediction System Ready For Deployment")

# %% [markdown]
# ## Deployment Steps
#
# 1. Train Model
# 2. Save Model
# 3. Build Streamlit Application
# 4. Test Application
# 5. Deploy Application

# %% [markdown]
# ## Summary
#
# - Prepared deployment package
# - Verified application
# - Completed deployment process
