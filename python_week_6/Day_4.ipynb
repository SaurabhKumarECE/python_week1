# %% [markdown]
# # WEEK 6 – DAY 4
# # System Integration

# %% [markdown]
# ## Objective
#
# Connect Machine Learning model with Streamlit interface.

# %% [markdown]
# ## What is System Integration?
#
# System integration combines:
#
# - Machine Learning Model
# - User Interface
# - Prediction System
#
# into one working application.

# %%
import joblib
import pandas as pd

# %%
# Load saved model

model = joblib.load(
    "best_house_price_model.pkl"
)

print("Model Loaded Successfully")
# Out:
# Model Loaded Successfully

# %%
sample_house = pd.DataFrame(
    {
        "Area": [2500],
        "Bedrooms": [5],
        "Bathrooms": [4],
        "Floors": [3],
        "Parking": [3]
    }
)

prediction = model.predict(sample_house)

print("Predicted Price:", prediction[0])
# Out:
# Predicted Price: 9110000.0

# %% [markdown]
# ## Integration Workflow
#
# User Input
#
# ↓
#
# Streamlit Dashboard
#
# ↓
#
# ML Model
#
# ↓
#
# Predicted House Price

# %% [markdown]
# ## Summary
#
# - Loaded trained model
# - Tested model integration
# - Prepared deployment interface
